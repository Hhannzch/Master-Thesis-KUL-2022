# %% [markdown]
# <a href="https://colab.research.google.com/github/Hhannzch/show-and-tell-baseline/blob/main/baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # try with pycocotools

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pycocotools
from pycocotools.coco import COCO

val_info = '/content/drive/MyDrive/coco/2017/annotations/instances_val2017.json'
val_image = '/content/drive/MyDrive/coco/2017/val2017'

coco = COCO(val_info)
all_ids = coco.imgs.keys()
print(len(all_ids))
# Out:
# loading annotations into memory...
# Done (t=6.03s)
# creating index...
# index created!
# 5000

# %%
id_list = list(all_ids)
print(id_list[1])
img_path = coco.loadImgs(id_list[1])
# Out:
# 37777

# %%
print(img_path[0]['file_name'])
# Out:
# 000000037777.jpg

# %%
print(img_path)

import matplotlib.pyplot as plt
img = plt.imread(val_image + '/' + str(img_path[0]['file_name']))
plt.imshow(img)
plt.show()
# Out:
# [{'license': 1, 'file_name': '000000037777.jpg', 'coco_url': 'http://images.cocodataset.org/val2017/000000037777.jpg', 'height': 230, 'width': 352, 'date_captured': '2013-11-14 20:55:31', 'flickr_url': 'http://farm9.staticflickr.com/8429/7839199426_f6d48aa585_z.jpg', 'id': 37777}]

# %%
# plt.imshow(img)
# plt.show()
plt.imshow(img)
plt.axis('off')
ann = coco.getAnnIds(img_path[0]['id'])
print(ann)
anns = coco.loadAnns(ann)
print(anns)
coco.showAnns(anns)
# mask = coco.annToMask(anns[3])
# plt.imshow(mask); plt.axis('off')
# Out:
# [22328, 100948, 102453, 120305, 330768, 1042181, 1122054, 1129584, 1556717, 1556915, 1559169, 1559287, 1944415, 2187566]
# ...

# %%
# Out:
# []
# []
